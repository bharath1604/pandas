# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas_profiling

# %%
manufacturing=pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/manufacturing%20process%20in%20a%20refinery.csv')

# %%
manufacturing
# Out:
#     Index  One  Material_1_amount  Material_2_amount  Material_3_amount  \
# 0       1    1              55.33               1.72                 54
# 1       2    1              59.13               1.20                 53
# 2       3    1              57.39               1.42                 55
# 3       4    1              56.43               1.78                 55
# 4       5    1              55.98               1.58                 54
# ..    ...  ...                ...                ...                ...
# 58     59    1              67.60               1.84                 55
# 59     60    1              64.81               2.24                 54
# 60     61    1              63.13               1.60                 52
# 61     62    1              63.48               3.46                 52
# 62     63    1              62.25               3.56                 50
#
#     Condition  Octane Number
# 0     1.66219          92.19
# 1     1.58399          92.74
# ...

# %%
manufacturing.to_csv('manufacturing.csv')

# %%
# !pip install xlrd
# Out:
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
df=pd.concat(pd.read_excel(r'C:\Users\91833\manufacturingdata.xlsx',sheet_name=None),ignore_index=True)

# %%
df
# Out:
#     Unnamed: 0  Index  One  Material_1_amount  Material_2_amount  \
# 0            0      1    1              55.33               1.72
# 1            1      2    1              59.13               1.20
# 2            2      3    1              57.39               1.42
# 3            3      4    1              56.43               1.78
# 4            4      5    1              55.98               1.58
# 5            5      6    1              56.16               2.12
# 6            6      7    1              54.85               1.17
# 7            7      8    1              52.83               1.50
# 8            8      9    1              54.52               0.87
# 9            9     10    1              60.93               1.22
# 10          10     11    1              57.51               0.87
# 11          11     12    1              62.82               0.88
# 12          12     13    1              62.57               0.42
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Index  One  Material_1_amount  Material_2_amount  \
# 0           0      1    1              55.33               1.72
# 1           1      2    1              59.13               1.20
# 2           2      3    1              57.39               1.42
# 3           3      4    1              56.43               1.78
# 4           4      5    1              55.98               1.58
#
#    Material_3_amount  Condition  Octane Number
# 0                 54    1.66219          92.19
# 1                 53    1.58399          92.74
# 2                 55    1.61731          91.88
# 3                 55    1.66228          92.80
# 4                 54    1.63195          92.56

# %%
df.tail()
# Out:
#     Unnamed: 0  Index  One  Material_1_amount  Material_2_amount  \
# 36          36     37    1              64.05               1.64
# 37          37     38    1              63.97               2.80
# 38          38     39    1              70.48               4.64
# 39          39     40    1              71.11               3.56
# 40          40     41    1              69.05               2.51
#
#     Material_3_amount  Condition  Octane Number
# 36                 57    1.33945          90.41
# 37                 60    1.42094          90.43
# 38                 60    1.57680          89.87
# 39                 60    1.41229          89.98
# 40                 60    1.54605          90.00

# %%
df.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0  Index  One  Material_1_amount  Material_2_amount  \
# 0            0      1    1              55.33               1.72
# 1            1      2    1              59.13               1.20
# 2            2      3    1              57.39               1.42
# 3            3      4    1              56.43               1.78
# 4            4      5    1              55.98               1.58
# 5            5      6    1              56.16               2.12
# 6            6      7    1              54.85               1.17
# 7            7      8    1              52.83               1.50
# 8            8      9    1              54.52               0.87
# 9            9     10    1              60.93               1.22
# 10          10     11    1              57.51               0.87
# 11          11     12    1              62.82               0.88
# 12          12     13    1              62.57               0.42
# ...

# %%
sns.heatmap(df)

# %%
pandas_profiling.ProfileReport(df)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.2.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
sns.pairplot(df)

# %%
manufacturing.ndim
# Out:
# 2

# %%
manufacturing.size
# Out:
# 441

# %%
manufacturing.dtypes
# Out:
# Index                  int64
# One                    int64
# Material_1_amount    float64
# Material_2_amount    float64
# Material_3_amount      int64
# Condition            float64
# Octane Number        float64
# dtype: object

# %%
df1=pd.DataFrame({'Height':[4.6,5.7,6.0],
                'Weight':[45,55,62]})

# %%
df1
# Out:
#    Height  Weight
# 0     4.6      45
# 1     5.7      55
# 2     6.0      62

# %%
df2=pd.DataFrame({'Name':['Bharath','shameer','mujju'],
                'age':[24,25,26]})

# %%
df2
# Out:
#       Name  age
# 0  Bharath   24
# 1  shameer   25
# 2    mujju   26

# %%
de=pd.concat([df1,df2],axis=0,sort=False)

# %%
de
# Out:
#    Height  Weight     Name   age
# 0     4.6    45.0      NaN   NaN
# 1     5.7    55.0      NaN   NaN
# 2     6.0    62.0      NaN   NaN
# 0     NaN     NaN  Bharath  24.0
# 1     NaN     NaN  shameer  25.0
# 2     NaN     NaN    mujju  26.0

# %%
de=pd.concat([df1,df2],axis=1,sort=False)

# %%
de
# Out:
#    Height  Weight     Name  age
# 0     4.6      45  Bharath   24
# 1     5.7      55  shameer   25
# 2     6.0      62    mujju   26

# %%
df1 = pd.DataFrame({'A': [1., np.nan, 3., 5., np.nan],  'B': [np.nan, 2., 3., np.nan, 6.]})
df2 = pd.DataFrame({'A': [5., 2., 4., np.nan, 3., 7.], 'B': [np.nan, np.nan, 3., 4., 6., 8.]})

# %%
df1
# Out:
#      A    B
# 0  1.0  NaN
# 1  NaN  2.0
# 2  3.0  3.0
# 3  5.0  NaN
# 4  NaN  6.0

# %%
df2
# Out:
#      A    B
# 0  5.0  NaN
# 1  2.0  NaN
# 2  4.0  3.0
# 3  NaN  4.0
# 4  3.0  6.0
# 5  7.0  8.0

# %%
df1.combine_first
# Out:
# <bound method DataFrame.combine_first of      A    B
# 0  1.0  NaN
# 1  NaN  2.0
# 2  3.0  3.0
# 3  5.0  NaN
# 4  NaN  6.0>

# %%
df1.mean(1)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    5.0
# 4    6.0
# dtype: float64

# %%
df1.median(0)
# Out:
# A    3.0
# B    3.0
# dtype: float64

# %%
df1.sum()
# Out:
# A     9.0
# B    11.0
# dtype: float64

# %%
df1.sum(0,skipna=False)
# Out:
# A   NaN
# B   NaN
# dtype: float64

# %%
df1.sum(0,skipna=True)
# Out:
# A     9.0
# B    11.0
# dtype: float64

# %%
df1.sum(1,skipna=True)
# Out:
# 0    1.0
# 1    2.0
# 2    6.0
# 3    5.0
# 4    6.0
# dtype: float64

# %%
df1.cumsum(0)
# Out:
#      A     B
# 0  1.0   NaN
# 1  NaN   2.0
# 2  4.0   5.0
# 3  9.0   NaN
# 4  NaN  11.0

# %%
df1.cumsum(1)
# Out:
#      A    B
# 0  1.0  NaN
# 1  NaN  2.0
# 2  3.0  6.0
# 3  5.0  NaN
# 4  NaN  6.0

# %%
frame = pd.DataFrame(np.random.randn(1000, 5),   columns=['a', 'b', 'c', 'd', 'e'])
frame.iloc[::2] = np.nan

# %%
frame
# Out:
#             a         b         c         d         e
# 0         NaN       NaN       NaN       NaN       NaN
# 1    0.951042  0.076366  0.946754  0.690456 -2.789100
# 2         NaN       NaN       NaN       NaN       NaN
# 3    0.832614  0.943641 -0.572319 -1.924382  1.057457
# 4         NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...
# 995 -0.625741  0.396648 -0.537696  1.057827  0.348558
# 996       NaN       NaN       NaN       NaN       NaN
# 997 -0.761678 -1.325211  0.254813 -2.271996 -0.252672
# 998       NaN       NaN       NaN       NaN       NaN
# 999  0.482182  0.115155 -0.626642 -0.378287  2.074188
#
# [1000 rows x 5 columns]

# %%
frame['f']=np.random.randn(1000)

# %%
frame
# Out:
#             a         b         c         d         e         f
# 0         NaN       NaN       NaN       NaN       NaN -0.205576
# 1    0.951042  0.076366  0.946754  0.690456 -2.789100  1.032532
# 2         NaN       NaN       NaN       NaN       NaN  0.384583
# 3    0.832614  0.943641 -0.572319 -1.924382  1.057457  0.937395
# 4         NaN       NaN       NaN       NaN       NaN -0.217258
# ..        ...       ...       ...       ...       ...       ...
# 995 -0.625741  0.396648 -0.537696  1.057827  0.348558  0.592264
# 996       NaN       NaN       NaN       NaN       NaN -0.885339
# 997 -0.761678 -1.325211  0.254813 -2.271996 -0.252672 -0.463189
# 998       NaN       NaN       NaN       NaN       NaN -1.557256
# 999  0.482182  0.115155 -0.626642 -0.378287  2.074188 -0.013931
#
# [1000 rows x 6 columns]

# %%
frame['g']=np.random.randn(1000)

# %%
frame
# Out:
#             a         b         c         d         e         f         g
# 0         NaN       NaN       NaN       NaN       NaN -0.205576 -0.463740
# 1    0.951042  0.076366  0.946754  0.690456 -2.789100  1.032532 -0.224978
# 2         NaN       NaN       NaN       NaN       NaN  0.384583 -0.646383
# 3    0.832614  0.943641 -0.572319 -1.924382  1.057457  0.937395  1.478837
# 4         NaN       NaN       NaN       NaN       NaN -0.217258  0.748149
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -0.625741  0.396648 -0.537696  1.057827  0.348558  0.592264  0.654614
# 996       NaN       NaN       NaN       NaN       NaN -0.885339  0.566762
# 997 -0.761678 -1.325211  0.254813 -2.271996 -0.252672 -0.463189  1.433112
# 998       NaN       NaN       NaN       NaN       NaN -1.557256 -1.777048
# 999  0.482182  0.115155 -0.626642 -0.378287  2.074188 -0.013931  0.398346
#
# [1000 rows x 7 columns]

# %%
df = pd.DataFrame(np.random.randn(10, 4))
pieces = [df[:3], df[3:7], df[7:]]

# %%
df
# Out:
#           0         1         2         3
# 0 -0.791355  1.612881 -0.423775 -0.204944
# 1  0.059208  0.967716 -0.288448 -0.510419
# 2 -0.382361  1.369150 -0.975611 -1.484978
# 3  1.177614  0.690892 -0.485863  0.045028
# 4  0.017097 -0.990509 -0.297104 -0.127668
# 5  0.193198 -0.030968 -0.849065  0.200102
# 6 -0.393118 -0.530400 -1.557609 -1.947955
# 7 -0.988316 -0.523867  0.570423 -0.163025
# 8  0.308542 -1.378029  1.690647 -0.100859
# 9 -0.396816  0.183844 -0.270640  0.844532

# %%
pieces
# Out:
# [          0         1         2         3
#  0 -0.791355  1.612881 -0.423775 -0.204944
#  1  0.059208  0.967716 -0.288448 -0.510419
#  2 -0.382361  1.369150 -0.975611 -1.484978,
#            0         1         2         3
#  3  1.177614  0.690892 -0.485863  0.045028
#  4  0.017097 -0.990509 -0.297104 -0.127668
#  5  0.193198 -0.030968 -0.849065  0.200102
#  6 -0.393118 -0.530400 -1.557609 -1.947955,
#            0         1         2         3
#  7 -0.988316 -0.523867  0.570423 -0.163025
#  8  0.308542 -1.378029  1.690647 -0.100859
#  9 -0.396816  0.183844 -0.270640  0.844532]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.791355  1.612881 -0.423775 -0.204944
# 1  0.059208  0.967716 -0.288448 -0.510419
# 2 -0.382361  1.369150 -0.975611 -1.484978
# 3  1.177614  0.690892 -0.485863  0.045028
# 4  0.017097 -0.990509 -0.297104 -0.127668
# 5  0.193198 -0.030968 -0.849065  0.200102
# 6 -0.393118 -0.530400 -1.557609 -1.947955
# 7 -0.988316 -0.523867  0.570423 -0.163025
# 8  0.308542 -1.378029  1.690647 -0.100859
# 9 -0.396816  0.183844 -0.270640  0.844532

# %%
pd.concat(pieces,axis=0)
# Out:
#           0         1         2         3
# 0 -0.791355  1.612881 -0.423775 -0.204944
# 1  0.059208  0.967716 -0.288448 -0.510419
# 2 -0.382361  1.369150 -0.975611 -1.484978
# 3  1.177614  0.690892 -0.485863  0.045028
# 4  0.017097 -0.990509 -0.297104 -0.127668
# 5  0.193198 -0.030968 -0.849065  0.200102
# 6 -0.393118 -0.530400 -1.557609 -1.947955
# 7 -0.988316 -0.523867  0.570423 -0.163025
# 8  0.308542 -1.378029  1.690647 -0.100859
# 9 -0.396816  0.183844 -0.270640  0.844532
