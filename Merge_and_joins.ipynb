# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas_profiling

# %% [markdown]
# # Merge and Joins

# %%
df1=pd.DataFrame({'employee':['Raju','Rani','Ramesh','Ram'],
                 'group':['Accounting','Engineering','Engineering','HR']})
df2=pd.DataFrame({'employee':['Raju','Rani','Ramesh','Ram'],
                 'hire_date':[2004,2008,2012,2014]})

# %%
df1
# Out:
#   employee        group
# 0     Raju   Accounting
# 1     Rani  Engineering
# 2   Ramesh  Engineering
# 3      Ram           HR

# %%
df2
# Out:
#   employee  hire_date
# 0     Raju       2004
# 1     Rani       2008
# 2   Ramesh       2012
# 3      Ram       2014

# %%
df3=pd.merge(df1,df2)

# %%
df3
# Out:
#   employee        group  hire_date
# 0     Raju   Accounting       2004
# 1     Rani  Engineering       2008
# 2   Ramesh  Engineering       2012
# 3      Ram           HR       2014

# %%
a=pd.concat([df1,df2],axis=0,sort=False,ignore_index=True)

# %%
a
# Out:
#   employee        group  hire_date
# 0     Raju   Accounting        NaN
# 1     Rani  Engineering        NaN
# 2   Ramesh  Engineering        NaN
# 3      Ram           HR        NaN
# 4     Raju          NaN     2004.0
# 5     Rani          NaN     2008.0
# 6   Ramesh          NaN     2012.0
# 7      Ram          NaN     2014.0

# %%
a=pd.concat([df1,df2],axis=1,sort=True,ignore_index=False)
a
# Out:
#   employee        group employee  hire_date
# 0     Raju   Accounting     Raju       2004
# 1     Rani  Engineering     Rani       2008
# 2   Ramesh  Engineering   Ramesh       2012
# 3      Ram           HR      Ram       2014

# %%
df4=pd.DataFrame({'group':['Accounting','Engineering','HR'],
                 'supervisor':['Carly','Guido','Steve']})
df4
# Out:
#          group supervisor
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve

# %%
pd.merge(df3,df4)
# Out:
#   employee        group  hire_date supervisor
# 0     Raju   Accounting       2004      Carly
# 1     Rani  Engineering       2008      Guido
# 2   Ramesh  Engineering       2012      Guido
# 3      Ram           HR       2014      Steve

# %%
df5=pd.DataFrame({'group':['Accounting','Accounting','Engineering','Engineering','HR','HR'],
                 'skills':['math','spreadsheets','coding','linux','spreadsheets','organisation']})
df5
# Out:
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR  organisation

# %%
pd.merge(df1,df5)
# Out:
#   employee        group        skills
# 0     Raju   Accounting          math
# 1     Raju   Accounting  spreadsheets
# 2     Rani  Engineering        coding
# 3     Rani  Engineering         linux
# 4   Ramesh  Engineering        coding
# 5   Ramesh  Engineering         linux
# 6      Ram           HR  spreadsheets
# 7      Ram           HR  organisation

# %%
pd.merge(df1,df2,on='employee')
# Out:
#   employee        group  hire_date
# 0     Raju   Accounting       2004
# 1     Rani  Engineering       2008
# 2   Ramesh  Engineering       2012
# 3      Ram           HR       2014

# %%
a=pd.DataFrame({'age':[20,22,24,25,26],
               'DOB':[2000,1998,1996,1995,1994],
               'Name':['Rajesh','Raju','Ravi','Mani','Santosh']})

# %%
b=pd.DataFrame({'Name':['Rajesh','Raju','Ravi','Mani','Santosh'],
               'age':[20,22,24,25,26],
               'Gender':['M','M','M','M','M']})

# %%
a
# Out:
#    age   DOB     Name
# 0   20  2000   Rajesh
# 1   22  1998     Raju
# 2   24  1996     Ravi
# 3   25  1995     Mani
# 4   26  1994  Santosh

# %%
b
# Out:
#       Name  age Gender
# 0   Rajesh   20      M
# 1     Raju   22      M
# 2     Ravi   24      M
# 3     Mani   25      M
# 4  Santosh   26      M

# %%
pd.merge(a,b)
# Out:
#    age   DOB     Name Gender
# 0   20  2000   Rajesh      M
# 1   22  1998     Raju      M
# 2   24  1996     Ravi      M
# 3   25  1995     Mani      M
# 4   26  1994  Santosh      M

# %%
pd.merge(a,b,on='Name')
# Out:
#    age_x   DOB     Name  age_y Gender
# 0     20  2000   Rajesh     20      M
# 1     22  1998     Raju     22      M
# 2     24  1996     Ravi     24      M
# 3     25  1995     Mani     25      M
# 4     26  1994  Santosh     26      M

# %%
pd.merge(a,b,on='age')
# Out:
#    age   DOB   Name_x   Name_y Gender
# 0   20  2000   Rajesh   Rajesh      M
# 1   22  1998     Raju     Raju      M
# 2   24  1996     Ravi     Ravi      M
# 3   25  1995     Mani     Mani      M
# 4   26  1994  Santosh  Santosh      M

# %%
pd.concat([a,b],axis=0,sort=False)
# Out:
#    age     DOB     Name Gender
# 0   20  2000.0   Rajesh    NaN
# 1   22  1998.0     Raju    NaN
# 2   24  1996.0     Ravi    NaN
# 3   25  1995.0     Mani    NaN
# 4   26  1994.0  Santosh    NaN
# 0   20     NaN   Rajesh      M
# 1   22     NaN     Raju      M
# 2   24     NaN     Ravi      M
# 3   25     NaN     Mani      M
# 4   26     NaN  Santosh      M

# %%
pd.concat([a,b],axis=1,sort=True)
# Out:
#    age   DOB     Name     Name  age Gender
# 0   20  2000   Rajesh   Rajesh   20      M
# 1   22  1998     Raju     Raju   22      M
# 2   24  1996     Ravi     Ravi   24      M
# 3   25  1995     Mani     Mani   25      M
# 4   26  1994  Santosh  Santosh   26      M

# %%
df3=pd.DataFrame({'name':['Raju','Rani','Ramesh','Ram'],
                 'salary':[70000,80000,120000,90000]})

# %%
df3
# Out:
#      name  salary
# 0    Raju   70000
# 1    Rani   80000
# 2  Ramesh  120000
# 3     Ram   90000

# %%
pd.merge(df1,df3,left_on='employee',right_on='name').drop('name',axis=1)
# Out:
#   employee        group  salary
# 0     Raju   Accounting   70000
# 1     Rani  Engineering   80000
# 2   Ramesh  Engineering  120000
# 3      Ram           HR   90000

# %% [markdown]
# # The left_index

# %%
df1a=df1.set_index('employee')
df2a=df2.set_index('employee')

# %%
df1a
# Out:
#                 group
# employee
# Raju       Accounting
# Rani      Engineering
# Ramesh    Engineering
# Ram                HR

# %%
df2a
# Out:
#           hire_date
# employee
# Raju           2004
# Rani           2008
# Ramesh         2012
# Ram            2014

# %%
pd.merge(df1a,df2a,left_index=True,right_index=True)
# Out:
#                 group  hire_date
# employee
# Raju       Accounting       2004
# Rani      Engineering       2008
# Ramesh    Engineering       2012
# Ram                HR       2014

# %%
df1a.join(df2a)
# Out:
#                 group  hire_date
# employee
# Raju       Accounting       2004
# Rani      Engineering       2008
# Ramesh    Engineering       2012
# Ram                HR       2014

# %% [markdown]
# # specifying Set Airthmetic for Joins

# %%
df6=pd.DataFrame({'name':['Peter','Paul','Mary'],
                 'food':['fish','beans','bread']},
                columns=['name','food'])
df7=pd.DataFrame({'name':['Mary','Joseph','Paul'],
                 'drink':['wine','beer','water']},
                columns=['name','drink'])

# %%
df6
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread

# %%
df7
# Out:
#      name  drink
# 0    Mary   wine
# 1  Joseph   beer
# 2    Paul  water

# %%
pd.merge(df6,df7)
# Out:
#    name   food  drink
# 0  Paul  beans  water
# 1  Mary  bread   wine

# %%
pd.merge(df6,df7,how='inner')
# Out:
#    name   food  drink
# 0  Paul  beans  water
# 1  Mary  bread   wine

# %%
pd.merge(df6,df7,how='outer')
# Out:
#      name   food  drink
# 0   Peter   fish    NaN
# 1    Paul  beans  water
# 2    Mary  bread   wine
# 3  Joseph    NaN   beer

# %%
pd.merge(df6,df7,how='left')
# Out:
#     name   food  drink
# 0  Peter   fish    NaN
# 1   Paul  beans  water
# 2   Mary  bread   wine

# %%
pd.merge(df6,df7,how='right')
# Out:
#      name   food  drink
# 0    Paul  beans  water
# 1    Mary  bread   wine
# 2  Joseph    NaN   beer

# %% [markdown]
# # Overlapping Column Names:The Suffixes keyword

# %%
df8=pd.DataFrame({'name':['Bob','Jake','Lisa','Sue'],
                 'rank':[1,2,3,4]})
df9=pd.DataFrame({'name':['Bob','Jake','Lisa','Sue'],
                 'rank':[3,1,4,2]})

# %%
pd.merge(df8,df9,on='name')
# Out:
#    name  rank_x  rank_y
# 0   Bob       1       3
# 1  Jake       2       1
# 2  Lisa       3       4
# 3   Sue       4       2

# %%
pd.merge(df8,df9,on='name',suffixes=['_L','_R'])
# Out:
#    name  rank_L  rank_R
# 0   Bob       1       3
# 1  Jake       2       1
# 2  Lisa       3       4
# 3   Sue       4       2
