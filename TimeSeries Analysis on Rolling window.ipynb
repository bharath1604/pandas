# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.read_csv(r'C:\Users\91833\Desktop\Fremont_Bridge_Bicycle_Counter.csv',index_col='Date',parse_dates=True)

# %%
a
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
# ...                                   ...                           ...
# 2020-02-29 19:00:00                  29.0                          11.0
# 2020-02-29 20:00:00                  27.0                           7.0
# 2020-02-29 21:00:00                  20.0                           9.0
# 2020-02-29 22:00:00                  15.0                           7.0
# 2020-02-29 23:00:00                  27.0                           8.0
#
#                      Fremont Bridge West Sidewalk
# Date
# ...

# %%
a.head()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0

# %%
a.tail()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2020-02-29 19:00:00                  29.0                          11.0
# 2020-02-29 20:00:00                  27.0                           7.0
# 2020-02-29 21:00:00                  20.0                           9.0
# 2020-02-29 22:00:00                  15.0                           7.0
# 2020-02-29 23:00:00                  27.0                           8.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2020-02-29 19:00:00                          18.0
# 2020-02-29 20:00:00                          20.0
# 2020-02-29 21:00:00                          11.0
# 2020-02-29 22:00:00                           8.0
# 2020-02-29 23:00:00                          19.0

# %%
a.info
# Out:
# <bound method DataFrame.info of                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
# ...                                   ...                           ...
# 2020-02-29 19:00:00                  29.0                          11.0
# 2020-02-29 20:00:00                  27.0                           7.0
# 2020-02-29 21:00:00                  20.0                           9.0
# 2020-02-29 22:00:00                  15.0                           7.0
# 2020-02-29 23:00:00                  27.0                           8.0
#
#                      Fremont Bridge West Sidewalk
# Date
# ...

# %%
a.describe()
# Out:
#        Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# count          64934.000000                  64934.000000
# mean             113.805033                     51.976191
# std              145.235402                     67.013247
# min                0.000000                      0.000000
# 25%               14.000000                      6.000000
# 50%               61.000000                     28.000000
# 75%              148.000000                     70.000000
# max             1097.000000                    698.000000
#
#        Fremont Bridge West Sidewalk
# count                  64934.000000
# mean                      61.828842
# std                       90.605138
# min                        0.000000
# 25%                        7.000000
# 50%                       30.000000
# 75%                       74.000000
# max                      850.000000

# %%
a.isna()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                 False                         False
# 2012-10-03 01:00:00                 False                         False
# 2012-10-03 02:00:00                 False                         False
# 2012-10-03 03:00:00                 False                         False
# 2012-10-03 04:00:00                 False                         False
# ...                                   ...                           ...
# 2020-02-29 19:00:00                 False                         False
# 2020-02-29 20:00:00                 False                         False
# 2020-02-29 21:00:00                 False                         False
# 2020-02-29 22:00:00                 False                         False
# 2020-02-29 23:00:00                 False                         False
#
#                      Fremont Bridge West Sidewalk
# Date
# ...

# %%
a.isna().sum()
# Out:
# Fremont Bridge Total            10
# Fremont Bridge East Sidewalk    10
# Fremont Bridge West Sidewalk    10
# dtype: int64

# %%
a.columns
# Out:
# Index(['Fremont Bridge Total', 'Fremont Bridge East Sidewalk',
#        'Fremont Bridge West Sidewalk'],
#       dtype='object')

# %%
a.dropna().describe()
# Out:
#        Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# count          64934.000000                  64934.000000
# mean             113.805033                     51.976191
# std              145.235402                     67.013247
# min                0.000000                      0.000000
# 25%               14.000000                      6.000000
# 50%               61.000000                     28.000000
# 75%              148.000000                     70.000000
# max             1097.000000                    698.000000
#
#        Fremont Bridge West Sidewalk
# count                  64934.000000
# mean                      61.828842
# std                       90.605138
# min                        0.000000
# 25%                        7.000000
# 50%                       30.000000
# 75%                       74.000000
# max                      850.000000

# %%
a.isna().sum()
# Out:
# Fremont Bridge Total            10
# Fremont Bridge East Sidewalk    10
# Fremont Bridge West Sidewalk    10
# dtype: int64

# %% [markdown]
# # Visualising the Data

# %%
# %matplotlib inline
import seaborn
seaborn.set()

# %%
a.plot()
plt.ylabel('Hourly Bicycle Count');

# %%
weekely=a.resample('W').sum()
weekely.head()
# Out:
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-07               14292.0                        7297.0
# 2012-10-14               16795.0                        8679.0
# 2012-10-21               15509.0                        7946.0
# 2012-10-28               13437.0                        6901.0
# 2012-11-04               12194.0                        6408.0
#
#             Fremont Bridge West Sidewalk
# Date
# 2012-10-07                        6995.0
# 2012-10-14                        8116.0
# 2012-10-21                        7563.0
# 2012-10-28                        6536.0
# 2012-11-04                        5786.0

# %%
weekely.plot(style=['.-','--','-'])
plt.ylabel('Weekely bicycle count');

# %%
a.plot(style=['.-','--','-'])
plt.ylabel('monthly bicycle count');

# %%
daily=a.resample('D').sum()
daily.head()
# Out:
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03                3521.0                        1760.0
# 2012-10-04                3475.0                        1708.0
# 2012-10-05                3148.0                        1558.0
# 2012-10-06                2006.0                        1080.0
# 2012-10-07                2142.0                        1191.0
#
#             Fremont Bridge West Sidewalk
# Date
# 2012-10-03                        1761.0
# 2012-10-04                        1767.0
# 2012-10-05                        1590.0
# 2012-10-06                         926.0
# 2012-10-07                         951.0

# %%
daily.plot(style=['.-','--','-'])
plt.ylabel('daily bicycle count');

# %%
daily.rolling(120,center=True).std().plot(style=[':','--','-'])  # Mean + std
plt.ylabel('mean hourly count');

# %%
daily.rolling(120,center=True).mean().plot(style=[':','--','-'])  # Mean + std
plt.ylabel('mean hourly count');

# %%
daily.rolling(50,center=True,win_type='gaussian').sum(std=10).plot(style=[':','--','-']);

# %%
by_time=a.groupby(a.index.time).sum()
by_time.head()
# Out:
#           Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 00:00:00               31362.0                       13307.0
# 01:00:00               16630.0                        7450.0
# 02:00:00               10874.0                        5223.0
# 03:00:00                8022.0                        4139.0
# 04:00:00               17868.0                        9466.0
#
#           Fremont Bridge West Sidewalk
# 00:00:00                       18055.0
# 01:00:00                        9180.0
# 02:00:00                        5651.0
# 03:00:00                        3883.0
# 04:00:00                        8402.0

# %%
plt.figure(figsize=(16,9))
hourly_ticks=4*60*60*np.arange(6)
by_time.plot(xticks=hourly_ticks,style=[':','--','-']);

# %%
by_weekday=a.groupby(a.index.dayofweek).sum()
by_weekday.head()
# Out:
#       Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 0                1239039.0                      551277.0
# 1                1320679.0                      590122.0
# 2                1312537.0                      586697.0
# 3                1247377.0                      561026.0
# 4                1124397.0                      504831.0
#
#       Fremont Bridge West Sidewalk
# Date
# 0                         687762.0
# 1                         730557.0
# 2                         725840.0
# 3                         686351.0
# 4                         619566.0

# %%
by_weekday.index=['Mon','Tues','Wed','Thurs','Fri','Sat','Sun']
by_weekday.plot(style=[':','--','-'])

# %%
weekend=np.where(a.index.weekday<5,'Weekday','Weekend')
weekend[0:50]
# Out:
# array(['Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday',
#        'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday',
#        'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday',
#        'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday',
#        'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday',
#        'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday',
#        'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday',
#        'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday', 'Weekday',
#        'Weekday', 'Weekday'], dtype='<U7')

# %%
by_time=a.groupby([weekend,a.index.time]).mean()
by_time.head()
# Out:
#                   Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Weekday 00:00:00              9.697879                      4.161924
#         01:00:00              4.809622                      2.166063
#         02:00:00              3.186239                      1.571650
#         03:00:00              2.739783                      1.431971
#         04:00:00              7.676668                      4.253492
#
#                   Fremont Bridge West Sidewalk
# Weekday 00:00:00                      5.535954
#         01:00:00                      2.643559
#         02:00:00                      1.614589
#         03:00:00                      1.307812
#         04:00:00                      3.423176

# %%
by_time.tail()
# Out:
#                   Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Weekend 19:00:00             55.494179                     27.413972
#         20:00:00             40.879690                     19.345408
#         21:00:00             29.236740                     13.644243
#         22:00:00             22.231565                     10.018111
#         23:00:00             17.618370                      7.284605
#
#                   Fremont Bridge West Sidewalk
# Weekend 19:00:00                     28.080207
#         20:00:00                     21.534282
#         21:00:00                     15.592497
#         22:00:00                     12.213454
#         23:00:00                     10.333765

# %%
fig,ax=plt.subplots(1,2,figsize=(16,8))
by_time.loc['Weekday'].plot(ax=ax[0],title='Weekdays',
                           xticks=hourly_ticks,style=[':','--','-'])
by_time.loc['Weekend'].plot(ax=ax[1],title='Weekends',
                           xticks=hourly_ticks,style=[':','--','-']);
