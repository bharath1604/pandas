# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas_profiling

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-abbrevs.csv')
df2=pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-areas.csv')
df3=pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/state-population.csv')

# %%
df1
# Out:
#                    state abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# ...

# %%
df2
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# ...

# %%
df3
# Out:
#      state/region     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]

# %%
a=pd.merge(df1,df3,how='outer',left_on='abbreviation',right_on='state/region')

# %%
a
# Out:
#         state abbreviation state/region     ages  year   population
# 0     Alabama           AL           AL  under18  2012    1117489.0
# 1     Alabama           AL           AL    total  2012    4817528.0
# 2     Alabama           AL           AL  under18  2010    1130966.0
# 3     Alabama           AL           AL    total  2010    4785570.0
# 4     Alabama           AL           AL  under18  2011    1125763.0
# ...       ...          ...          ...      ...   ...          ...
# 2539      NaN          NaN          USA    total  2010  309326295.0
# 2540      NaN          NaN          USA  under18  2011   73902222.0
# 2541      NaN          NaN          USA    total  2011  311582564.0
# 2542      NaN          NaN          USA  under18  2012   73708179.0
# 2543      NaN          NaN          USA    total  2012  313873685.0
#
# [2544 rows x 6 columns]

# %%
a.head()
# Out:
#      state state/region     ages  year  population
# 0  Alabama           AL  under18  2012   1117489.0
# 1  Alabama           AL    total  2012   4817528.0
# 2  Alabama           AL  under18  2010   1130966.0
# 3  Alabama           AL    total  2010   4785570.0
# 4  Alabama           AL  under18  2011   1125763.0

# %%
a=a.drop('abbreviation',1)

# %%
a
# Out:
#         state state/region     ages  year   population
# 0     Alabama           AL  under18  2012    1117489.0
# 1     Alabama           AL    total  2012    4817528.0
# 2     Alabama           AL  under18  2010    1130966.0
# 3     Alabama           AL    total  2010    4785570.0
# 4     Alabama           AL  under18  2011    1125763.0
# ...       ...          ...      ...   ...          ...
# 2539      NaN          USA    total  2010  309326295.0
# 2540      NaN          USA  under18  2011   73902222.0
# 2541      NaN          USA    total  2011  311582564.0
# 2542      NaN          USA  under18  2012   73708179.0
# 2543      NaN          USA    total  2012  313873685.0
#
# [2544 rows x 5 columns]

# %%
a.isna().sum()
# Out:
# state           96
# state/region     0
# ages             0
# year             0
# population      20
# dtype: int64

# %%
a['population'].isna().sum()
# Out:
# 20

# %%
a['state'].isna().sum()
# Out:
# 96

# %%
a[a['population'].isnull()]
# Out:
#      state state/region     ages  year  population
# 2448   NaN           PR  under18  1990         NaN
# 2449   NaN           PR    total  1990         NaN
# 2450   NaN           PR    total  1991         NaN
# 2451   NaN           PR  under18  1991         NaN
# 2452   NaN           PR    total  1993         NaN
# 2453   NaN           PR  under18  1993         NaN
# 2454   NaN           PR  under18  1992         NaN
# 2455   NaN           PR    total  1992         NaN
# 2456   NaN           PR  under18  1994         NaN
# 2457   NaN           PR    total  1994         NaN
# 2458   NaN           PR    total  1995         NaN
# 2459   NaN           PR  under18  1995         NaN
# 2460   NaN           PR  under18  1996         NaN
# 2461   NaN           PR    total  1996         NaN
# 2462   NaN           PR  under18  1998         NaN
# 2463   NaN           PR    total  1998         NaN
# 2464   NaN           PR    total  1997         NaN
# ...

# %%
a[a['state'].isnull()]
# Out:
#      state state/region     ages  year   population
# 2448   NaN           PR  under18  1990          NaN
# 2449   NaN           PR    total  1990          NaN
# 2450   NaN           PR    total  1991          NaN
# 2451   NaN           PR  under18  1991          NaN
# 2452   NaN           PR    total  1993          NaN
# ...    ...          ...      ...   ...          ...
# 2539   NaN          USA    total  2010  309326295.0
# 2540   NaN          USA  under18  2011   73902222.0
# 2541   NaN          USA    total  2011  311582564.0
# 2542   NaN          USA  under18  2012   73708179.0
# 2543   NaN          USA    total  2012  313873685.0
#
# [96 rows x 5 columns]

# %%
a.loc[a['state'].isnull(),'state/region'].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
a.loc[a['state/region']=='PR','stste']='Puerto Rico'
a.loc[a['state/region']=='USA','state']='United States'

# %%
a.isnull().any()
# Out:
# state            True
# state/region    False
# ages            False
# year            False
# population       True
# stste            True
# dtype: bool

# %%
b=pd.merge(a,df2,on='state',how='left')

# %%
b
# Out:
#         state abbreviation state/region     ages  year   population  \
# 0     Alabama           AL           AL  under18  2012    1117489.0
# 1     Alabama           AL           AL    total  2012    4817528.0
# 2     Alabama           AL           AL  under18  2010    1130966.0
# 3     Alabama           AL           AL    total  2010    4785570.0
# 4     Alabama           AL           AL  under18  2011    1125763.0
# ...       ...          ...          ...      ...   ...          ...
# 2539      NaN          NaN          USA    total  2010  309326295.0
# 2540      NaN          NaN          USA  under18  2011   73902222.0
# 2541      NaN          NaN          USA    total  2011  311582564.0
# 2542      NaN          NaN          USA  under18  2012   73708179.0
# 2543      NaN          NaN          USA    total  2012  313873685.0
#
#       area (sq. mi)
# 0           52423.0
# 1           52423.0
# 2           52423.0
# 3           52423.0
# 4           52423.0
# ...             ...
# ...

# %%
b.isna().sum()
# Out:
# state            96
# abbreviation     96
# state/region      0
# ages              0
# year              0
# population       20
# area (sq. mi)    96
# dtype: int64

# %%
b['state'][final['state'].isnull()].unique()
# Out:
# array([nan], dtype=object)

# %%
data2010=b.query("year==2010 & ages=='total'")

# %%
data2010
# Out:
#                      state abbreviation state/region   ages  year  \
# 3                  Alabama           AL           AL  total  2010
# 91                  Alaska           AK           AK  total  2010
# 101                Arizona           AZ           AZ  total  2010
# 189               Arkansas           AR           AR  total  2010
# 197             California           CA           CA  total  2010
# 283               Colorado           CO           CO  total  2010
# 293            Connecticut           CT           CT  total  2010
# 379               Delaware           DE           DE  total  2010
# 389   District of Columbia           DC           DC  total  2010
# 475                Florida           FL           FL  total  2010
# 485                Georgia           GA           GA  total  2010
# 570                 Hawaii           HI           HI  total  2010
# 581                  Idaho           ID           ID  total  2010
# ...

# %%
data2010.set_index('state',inplace=True)
data2010
# Out:
#                      abbreviation state/region   ages  year   population  \
# state
# Alabama                        AL           AL  total  2010    4785570.0
# Alaska                         AK           AK  total  2010     713868.0
# Arizona                        AZ           AZ  total  2010    6408790.0
# Arkansas                       AR           AR  total  2010    2922280.0
# California                     CA           CA  total  2010   37333601.0
# Colorado                       CO           CO  total  2010    5048196.0
# Connecticut                    CT           CT  total  2010    3579210.0
# Delaware                       DE           DE  total  2010     899711.0
# District of Columbia           DC           DC  total  2010     605125.0
# Florida                        FL           FL  total  2010   18846054.0
# Georgia                        GA           GA  total  2010    9713248.0
# Hawaii                         HI           HI  total  2010    1363731.0
# ...

# %%
density=data2010['population']/data2010['area (sq. mi)']

# %%
density.head()
# Out:
# state
# Alabama        91.287603
# Alaska          1.087509
# Arizona        56.214497
# Arkansas       54.948667
# California    228.051342
# dtype: float64

# %%
density.sort_values(ascending=True,inplace=True)

# %%
density
# Out:
# state
# Alaska                     1.087509
# Wyoming                    5.768079
# Montana                    6.736171
# North Dakota               9.537565
# South Dakota              10.583512
# New Mexico                16.982737
# Idaho                     18.794338
# Nebraska                  23.654153
# Nevada                    24.448796
# Utah                      32.677188
# Kansas                    34.745266
# Maine                     37.509990
# Oregon                    39.001565
# Colorado                  48.493718
# Oklahoma                  53.778278
# Iowa                      54.202751
# Arkansas                  54.948667
# Arizona                   56.214497
# Minnesota                 61.078373
# Mississippi               61.321530
# Vermont                   65.085075
# West Virginia             76.519582
# Missouri                  86.015622
# Wisconsin                 86.851900
# Louisiana                 87.676099
# Alabama                   91.287603
# ...

# %%
b.isnull().describe()
# Out:
#         state abbreviation state/region   ages   year population area (sq. mi)
# count    2544         2544         2544   2544   2544       2544          2544
# unique      2            2            1      1      1          2             2
# top     False        False        False  False  False      False         False
# freq     2448         2448         2544   2544   2544       2524          2448

# %%
c=a.to_pickle('US_states_Data.plk')

# %%
unpickled_df=pd.read_pickle('US_states_Data.plk')

# %%
unpickled_df
# Out:
#         state abbreviation state/region     ages  year   population
# 0     Alabama           AL           AL  under18  2012    1117489.0
# 1     Alabama           AL           AL    total  2012    4817528.0
# 2     Alabama           AL           AL  under18  2010    1130966.0
# 3     Alabama           AL           AL    total  2010    4785570.0
# 4     Alabama           AL           AL  under18  2011    1125763.0
# ...       ...          ...          ...      ...   ...          ...
# 2539      NaN          NaN          USA    total  2010  309326295.0
# 2540      NaN          NaN          USA  under18  2011   73902222.0
# 2541      NaN          NaN          USA    total  2011  311582564.0
# 2542      NaN          NaN          USA  under18  2012   73708179.0
# 2543      NaN          NaN          USA    total  2012  313873685.0
#
# [2544 rows x 6 columns]

# %%
df=pd.DataFrame([[10,20,30,40],
               [10.256,3.54,75.86,50.5],
               ['Hi','Hello','Day','Month'],
               [np.nan,np.nan,np.nan,np.nan]],columns=['int','float','string','data'])
#df.agr(['min','sum'])columns=['int','float','string','data'])

# %%
df
# Out:
#       int  float string   data
# 0      10     20     30     40
# 1  10.256   3.54  75.86   50.5
# 2      Hi  Hello    Day  Month
# 3     NaN    NaN    NaN    NaN

# %%
Df=pd.DataFrame({'Name':['Balaji','Rajaram'],
                'Age':[24,106],
                'Data':[np.nan,0.0]})

# %%
Df
# Out:
#       Name  Age  Data
# 0   Balaji   24   NaN
# 1  Rajaram  106   0.0

# %%
Df.agg(['min','sum'])
# Out:
#               Name  Age  Data
# min         Balaji   24   0.0
# sum  BalajiRajaram  130   0.0

# %%
Df.agg({'Name':['sum','min'],
       'Age':['min','median']})
# Out:
#                  Name   Age
# median            NaN  65.0
# min            Balaji  24.0
# sum     BalajiRajaram   NaN
