# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas_profiling

# %%
rain=pd.read_csv(r'C:\Users\91833\Desktop\rainfall.csv')

# %%
rain
# Out:
#     Dmcode              Mandal  Cumm Actual Rainfall  Cumm Normal Rainfall  \
# 0     1001        Peddamandyam                 564.4                 567.0
# 1     1002      Thamballapalle                 586.5                 722.8
# 2     1003     Mulakalacheruvu                 480.6                 544.1
# 3     1004  Peddathippasamudra                 423.7                 652.9
# 4     1005         B Kothakota                 558.1                 545.6
# ..     ...                 ...                   ...                   ...
# 61    1062    Venkatagiri Kota                 547.6                 721.3
# 62    1063         Rama Kuppam                 535.0                 665.3
# 63    1064        Santhi Puram                 479.3                 717.0
# 64    1065          Gudi Palle                 476.8                 725.6
# 65    1066              Kuppam                 454.2                 737.1
#
# ...

# %%
rain.head()
# Out:
#    Dmcode              Mandal  Cumm Actual Rainfall  Cumm Normal Rainfall  \
# 0    1001        Peddamandyam                 564.4                 567.0
# 1    1002      Thamballapalle                 586.5                 722.8
# 2    1003     Mulakalacheruvu                 480.6                 544.1
# 3    1004  Peddathippasamudra                 423.7                 652.9
# 4    1005         B Kothakota                 558.1                 545.6
#
#    Deviation     Status             Predominant Crops Irrigation(area)
# 0       -0.5     Normal    Groundnut,Tomatoes,Mangoes      non-command
# 1      -18.9     Normal  Groundnut,Tomatoes,Horsegram      non-command
# 2      -11.7     Normal    Groundnut,Tomatoes,Redgram          command
# 3      -35.1  Deficient    Groundnut,Tomatoes,Redgram      non-command
# 4        2.3     Normal    Groundnut,Mangoes,Tomatoes      non-command

# %%
rain.tail()
# Out:
#     Dmcode            Mandal  Cumm Actual Rainfall  Cumm Normal Rainfall  \
# 61    1062  Venkatagiri Kota                 547.6                 721.3
# 62    1063       Rama Kuppam                 535.0                 665.3
# 63    1064      Santhi Puram                 479.3                 717.0
# 64    1065        Gudi Palle                 476.8                 725.6
# 65    1066            Kuppam                 454.2                 737.1
#
#     Deviation     Status                 Predominant Crops Irrigation(area)
# 61      -24.1  Deficient  Groundnut,Mangoes,Mulberry Trees      non-command
# 62      -19.6  Deficient  Groundnut,Mangoes,Mulberry Trees      non-command
# 63      -33.2  Deficient               Groundnut,Ragi,Rice      non-command
# 64      -34.3  Deficient          Ragi,Groundnut,Horsegram      non-command
# 65      -38.4  Deficient          Groundnut,Ragi,Horsegram      non-command

# %%
rain.isna()
# Out:
#     Dmcode  Mandal  Cumm Actual Rainfall  Cumm Normal Rainfall  Deviation  \
# 0    False   False                 False                 False      False
# 1    False   False                 False                 False      False
# 2    False   False                 False                 False      False
# 3    False   False                 False                 False      False
# 4    False   False                 False                 False      False
# ..     ...     ...                   ...                   ...        ...
# 61   False   False                 False                 False      False
# 62   False   False                 False                 False      False
# 63   False   False                 False                 False      False
# 64   False   False                 False                 False      False
# 65   False   False                 False                 False      False
#
#     Status  Predominant Crops  Irrigation(area)
# ...

# %%
rain.isna().sum()
# Out:
# Dmcode                  0
# Mandal                  0
# Cumm Actual Rainfall    0
# Cumm Normal Rainfall    0
# Deviation               0
# Status                  0
# Predominant Crops       0
# Irrigation(area)        0
# dtype: int64

# %%
rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 8 columns):
# Dmcode                  66 non-null int64
# Mandal                  66 non-null object
# Cumm Actual Rainfall    66 non-null float64
# Cumm Normal Rainfall    66 non-null float64
# Deviation               66 non-null float64
# Status                  66 non-null object
# Predominant Crops       66 non-null object
# Irrigation(area)        66 non-null object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 4.2+ KB

# %%
rain.shape
# Out:
# (66, 8)

# %%
rain.size
# Out:
# 528

# %%
rain.describe()
# Out:
#             Dmcode  Cumm Actual Rainfall  Cumm Normal Rainfall  Deviation
# count    66.000000             66.000000             66.000000  66.000000
# mean   1033.500000            801.810606            846.995455  -5.745455
# std      19.196354            234.223659            172.554134  19.016108
# min    1001.000000            338.600000            544.100000 -56.700000
# 25%    1017.250000            569.925000            720.100000 -18.550000
# 50%    1033.500000            811.700000            797.300000  -6.950000
# 75%    1049.750000           1005.425000            981.725000   9.625000
# max    1066.000000           1206.200000           1218.900000  33.500000

# %%
pandas_profiling.ProfileReport(rain)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.2.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
rain.columns
# Out:
# Index(['Dmcode', 'Mandal', 'Cumm_Actual_Rainfall', 'Cumm_Normal_Rainfall',
#        'Deviation', 'Status', 'Predominant_Crops', 'Irrigation(area)'],
#       dtype='object')

# %%
rain.mean()
# Out:
# Dmcode                  1033.500000
# Cumm_Actual_Rainfall     801.810606
# Cumm_Normal_Rainfall     846.995455
# Deviation                 -5.745455
# dtype: float64

# %%
rain.median()
# Out:
# Dmcode                  1033.50
# Cumm_Actual_Rainfall     811.70
# Cumm_Normal_Rainfall     797.30
# Deviation                 -6.95
# dtype: float64

# %%
rain.max()
# Out:
# Dmcode                                                               1066
# Mandal                                                            Yerpedu
# Cumm_Actual_Rainfall                                               1206.2
# Cumm_Normal_Rainfall                                               1218.9
# Deviation                                                            33.5
# Status                                                             Normal
# Predominant_Crops       Sugarcane Ratoon ( Harvest),Sugarcane Planted ...
# Irrigation(area)                                              non-command
# dtype: object

# %%
rain.min()
# Out:
# Dmcode                                                         1001
# Mandal                                                  B Kothakota
# Cumm_Actual_Rainfall                                          338.6
# Cumm_Normal_Rainfall                                          544.1
# Deviation                                                     -56.7
# Status                                                    Deficient
# Predominant_Crops       Bajra,Groundnut,Sugarcane Ratoon ( Harvest)
# Irrigation(area)                                            command
# dtype: object

# %%
rain.std()
# Out:
# Dmcode                   19.196354
# Cumm_Actual_Rainfall    234.223659
# Cumm_Normal_Rainfall    172.554134
# Deviation                19.016108
# dtype: float64

# %%
sns.heatmap(rain.corr())

# %%
a = np.array(['a','b','c'])
a
# Out:
# array(['a', 'b', 'c'], dtype='<U1')

# %%
a.tolist().index('b')
# Out:
# 1
